# %% [markdown]
# # Master Parquet Merge — Swap PrISM + Add UTD-MHAD
#
# 1. Load existing master parquet
# 2. Drop old `prism` rows
# 3. Concat new PrISM (procedural sub-task labels) + UTD-MHAD
# 4. Sanity-check row counts per dataset
# 5. Save

# %%
import pyarrow as pa
import pyarrow.parquet as pq
import pyarrow.compute as pc
from pathlib import Path
from collections import Counter

TEMP = Path("/home/aidan/IMU_LM_Data/Unification/temp")

master_path = TEMP / "IMULM_master_dataset.parquet"
prism_path  = TEMP / "prism_clean_data_procedural.parquet"
utd_path    = TEMP / "utd_mhad_clean_data.parquet"
out_path    = TEMP / "IMULM_master_dataset_v2.parquet"

# ---- 1. Inspect master metadata (no full load) ----
pf = pq.ParquetFile(master_path)
print(f"Master: {pf.metadata.num_rows:,} rows, {pf.metadata.num_row_groups} row groups")
print(f"Columns: {pf.schema_arrow.names}")

# ---- 2. Load the two small tables ----
print("\nLoading new PrISM...")
prism_new = pq.read_table(prism_path)
print(f"  PrISM rows: {prism_new.num_rows:,}, subjects: {len(pc.unique(prism_new.column('subject_id')))}, "
      f"sessions: {len(pc.unique(prism_new.column('session_id')))}, "
      f"labels: {len(pc.unique(prism_new.column('dataset_activity_label')))}")

print("Loading UTD-MHAD...")
utd = pq.read_table(utd_path)
print(f"  UTD-MHAD rows: {utd.num_rows:,}, subjects: {len(pc.unique(utd.column('subject_id')))}, "
      f"sessions: {len(pc.unique(utd.column('session_id')))}, "
      f"labels: {len(pc.unique(utd.column('dataset_activity_label')))}")

# ---- 3. Schema check (against master) ----
print("\n=== SCHEMA CHECK ===")
master_schema = pf.schema_arrow
for tbl_name, tbl in [("prism", prism_new), ("utd", utd)]:
    for col in master_schema.names:
        if col not in tbl.schema.names:
            print(f"  MISSING {col} in {tbl_name}")
    for col in tbl.schema.names:
        if col not in master_schema.names:
            print(f"  EXTRA {col} in {tbl_name}")
print("Schema check done (int16→int32 promotion handled automatically).")

# ---- 4. Stream master row-by-row-group, drop prism, write to v2 ----
print(f"\nStreaming master → {out_path.name} (dropping prism rows)...")
writer = None
before_counts = Counter()
rows_written = 0
prism_dropped = 0

for i in range(pf.metadata.num_row_groups):
    rg = pf.read_row_group(i)
    ds_col = rg.column("dataset")
    
    # Count before
    vc = pc.value_counts(ds_col)
    for item in vc.to_pylist():
        before_counts[item["values"]] += item["counts"]
    
    # Filter out prism
    keep = pc.not_equal(ds_col, "prism")
    n_prism = rg.num_rows - pc.sum(keep.cast(pa.int64())).as_py()
    prism_dropped += n_prism
    
    if n_prism < rg.num_rows:  # at least some non-prism rows
        filtered = rg.filter(keep)
        if writer is None:
            writer = pq.ParquetWriter(out_path, filtered.schema)
        writer.write_table(filtered)
        rows_written += filtered.num_rows
    
    if (i + 1) % 10 == 0 or i == pf.metadata.num_row_groups - 1:
        print(f"  Row group {i+1}/{pf.metadata.num_row_groups} — written: {rows_written:,}, prism dropped: {prism_dropped:,}")

# ---- 5. Append new PrISM + UTD-MHAD ----
print("\nAppending new PrISM...")
# Cast int16 → int32 to match master schema
for col in ["global_activity_id", "dataset_activity_id"]:
    if prism_new.schema.field(col).type != pa.int32():
        prism_new = prism_new.set_column(
            prism_new.schema.get_field_index(col), col,
            prism_new.column(col).cast(pa.int32()))
    if utd.schema.field(col).type != pa.int32():
        utd = utd.set_column(
            utd.schema.get_field_index(col), col,
            utd.column(col).cast(pa.int32()))

writer.write_table(prism_new)
rows_written += prism_new.num_rows
print(f"  +{prism_new.num_rows:,} PrISM rows")

print("Appending UTD-MHAD...")
writer.write_table(utd)
rows_written += utd.num_rows
print(f"  +{utd.num_rows:,} UTD-MHAD rows")

writer.close()
print(f"\nDone! Wrote {rows_written:,} total rows to {out_path.name}")

# ---- 6. Summary ----
print("\n=== BEFORE (master) ===")
for ds in sorted(before_counts):
    print(f"  {ds:20s} {before_counts[ds]:>12,}")
print(f"  {'TOTAL':20s} {sum(before_counts.values()):>12,}")

after_counts = dict(before_counts)
after_counts.pop("prism", None)
after_counts["prism"] = prism_new.num_rows
after_counts["utd_mhad"] = after_counts.get("utd_mhad", 0) + utd.num_rows

print("\n=== AFTER (v2) ===")
for ds in sorted(after_counts):
    print(f"  {ds:20s} {after_counts[ds]:>12,}")
print(f"  {'TOTAL':20s} {rows_written:>12,}")
print(f"\nTotal datasets: {len(after_counts)}")
print(f"File size: {out_path.stat().st_size / 1e9:.2f} GB")
# Out:
# Master: 734,080,597 rows, 741 row groups
# Columns: ['dataset', 'subject_id', 'session_id', 'timestamp_ns', 'acc_x', 'acc_y', 'acc_z', 'gyro_x', 'gyro_y', 'gyro_z', 'global_activity_id', 'global_activity_label', 'dataset_activity_id', 'dataset_activity_label']
#
# Loading new PrISM...
#   PrISM rows: 2,928,148, subjects: 31, sessions: 20, labels: 96
# Loading UTD-MHAD...
#   UTD-MHAD rows: 119,897, subjects: 8, sessions: 84, labels: 21
#
# === SCHEMA CHECK ===
# Schema check done (int16→int32 promotion handled automatically).
#
# Streaming master → IMULM_master_dataset_v2.parquet (dropping prism rows)...
#   Row group 10/741 — written: 9,256,462, prism dropped: 0
#   Row group 20/741 — written: 18,206,135, prism dropped: 0
#   Row group 30/741 — written: 26,815,817, prism dropped: 0
#   Row group 40/741 — written: 36,815,817, prism dropped: 0
#   Row group 50/741 — written: 46,815,817, prism dropped: 0
#   Row group 60/741 — written: 56,815,817, prism dropped: 0
#   Row group 70/741 — written: 66,815,817, prism dropped: 0
#   Row group 80/741 — written: 76,815,817, prism dropped: 0
#   Row group 90/741 — written: 86,815,817, prism dropped: 0
#   Row group 100/741 — written: 96,815,817, prism dropped: 0
#   Row group 110/741 — written: 106,815,817, prism dropped: 0
#   Row group 120/741 — written: 116,815,817, prism dropped: 0
#   Row group 130/741 — written: 126,815,817, prism dropped: 0
#   Row group 140/741 — written: 136,815,817, prism dropped: 0
#   Row group 150/741 — written: 146,815,817, prism dropped: 0
#   Row group 160/741 — written: 156,815,817, prism dropped: 0
#   Row group 170/741 — written: 166,815,817, prism dropped: 0
#   Row group 180/741 — written: 176,815,817, prism dropped: 0
#   Row group 190/741 — written: 186,815,817, prism dropped: 0
#   Row group 200/741 — written: 196,815,817, prism dropped: 0
#   Row group 210/741 — written: 206,815,817, prism dropped: 0
#   Row group 220/741 — written: 216,815,817, prism dropped: 0
#   Row group 230/741 — written: 226,815,817, prism dropped: 0
#   Row group 240/741 — written: 236,815,817, prism dropped: 0
#   Row group 250/741 — written: 246,815,817, prism dropped: 0
#   Row group 260/741 — written: 256,815,817, prism dropped: 0
#   Row group 270/741 — written: 266,815,817, prism dropped: 0
#   Row group 280/741 — written: 276,815,817, prism dropped: 0
#   Row group 290/741 — written: 286,815,817, prism dropped: 0
#   Row group 300/741 — written: 296,815,817, prism dropped: 0
#   Row group 310/741 — written: 306,815,817, prism dropped: 0
#   Row group 320/741 — written: 316,815,817, prism dropped: 0
#   Row group 330/741 — written: 326,815,817, prism dropped: 0
#   Row group 340/741 — written: 336,815,817, prism dropped: 0
#   Row group 350/741 — written: 346,815,817, prism dropped: 0
#   Row group 360/741 — written: 356,815,817, prism dropped: 0
#   Row group 370/741 — written: 366,815,817, prism dropped: 0
#   Row group 380/741 — written: 376,815,817, prism dropped: 0
#   Row group 390/741 — written: 386,815,817, prism dropped: 0
#   Row group 400/741 — written: 396,815,817, prism dropped: 0
#   Row group 410/741 — written: 406,815,817, prism dropped: 0
#   Row group 420/741 — written: 416,815,817, prism dropped: 0
#   Row group 430/741 — written: 426,815,817, prism dropped: 0
#   Row group 440/741 — written: 436,815,817, prism dropped: 0
#   Row group 450/741 — written: 446,815,817, prism dropped: 0
#   Row group 460/741 — written: 456,815,817, prism dropped: 0
#   Row group 470/741 — written: 466,815,817, prism dropped: 0
#   Row group 480/741 — written: 476,815,817, prism dropped: 0
#   Row group 490/741 — written: 486,815,817, prism dropped: 0
#   Row group 500/741 — written: 496,815,817, prism dropped: 0
#   Row group 510/741 — written: 506,815,817, prism dropped: 0
#   Row group 520/741 — written: 516,815,817, prism dropped: 0
#   Row group 530/741 — written: 526,815,817, prism dropped: 0
#   Row group 540/741 — written: 536,815,817, prism dropped: 0
#   Row group 550/741 — written: 546,815,817, prism dropped: 0
#   Row group 560/741 — written: 556,815,817, prism dropped: 0
#   Row group 570/741 — written: 566,815,817, prism dropped: 0
#   Row group 580/741 — written: 576,815,817, prism dropped: 0
#   Row group 590/741 — written: 586,815,817, prism dropped: 0
#   Row group 600/741 — written: 596,815,817, prism dropped: 0
#   Row group 610/741 — written: 606,815,817, prism dropped: 0
#   Row group 620/741 — written: 616,815,817, prism dropped: 0
#   Row group 630/741 — written: 626,815,817, prism dropped: 0
#   Row group 640/741 — written: 636,815,817, prism dropped: 0
#   Row group 650/741 — written: 646,815,817, prism dropped: 0
#   Row group 660/741 — written: 656,815,817, prism dropped: 0
#   Row group 670/741 — written: 666,815,817, prism dropped: 0
#   Row group 680/741 — written: 676,815,817, prism dropped: 0
#   Row group 690/741 — written: 686,815,817, prism dropped: 0
#   Row group 700/741 — written: 696,815,817, prism dropped: 0
#   Row group 710/741 — written: 706,815,817, prism dropped: 0
#   Row group 720/741 — written: 716,815,817, prism dropped: 0
#   Row group 730/741 — written: 721,827,763, prism dropped: 3,037,272
#   Row group 740/741 — written: 730,997,763, prism dropped: 3,037,272
#   Row group 741/741 — written: 731,043,325, prism dropped: 3,037,272
#
# Appending new PrISM...
#   +2,928,148 PrISM rows
# Appending UTD-MHAD...
#   +119,897 UTD-MHAD rows
#
# Done! Wrote 734,091,370 total rows to IMULM_master_dataset_v2.parquet
#
# === BEFORE (master) ===
#   capture24             699,011,946
#   opportunity++             985,421
#   pamap2                  1,271,041
#   prism                   3,037,272
#   recofit                 7,745,018
#   samosa                  1,204,655
#   shoaib                  1,170,000
#   ut_watch                8,146,709
#   wear                    3,462,973
#   wisdm                   8,045,562
#   TOTAL                 734,080,597
#
# === AFTER (v2) ===
#   capture24             699,011,946
#   opportunity++             985,421
#   pamap2                  1,271,041
#   prism                   2,928,148
#   recofit                 7,745,018
#   samosa                  1,204,655
#   shoaib                  1,170,000
#   ut_watch                8,146,709
#   utd_mhad                  119,897
#   wear                    3,462,973
#   wisdm                   8,045,562
#   TOTAL                 734,091,370
#
# Total datasets: 11
# File size: 13.34 GB

# %%
# ---- Optional: verify the output file ----
pf_out = pq.ParquetFile(out_path)
print(f"Output: {pf_out.metadata.num_rows:,} rows, {pf_out.metadata.num_row_groups} row groups")
print(f"Schema: {pf_out.schema_arrow}")
# Out:
# Output: 734,091,370 rows, 741 row groups
# Schema: dataset: string
# subject_id: string
# session_id: string
# timestamp_ns: int64
# acc_x: float
# acc_y: float
# acc_z: float
# gyro_x: float
# gyro_y: float
# gyro_z: float
# global_activity_id: int32
# global_activity_label: string
# dataset_activity_id: int32
# dataset_activity_label: string
